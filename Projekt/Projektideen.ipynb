# %% [markdown]
# <img src="./assets/Creative Djinn Logo Alpha.png" style="height: 100px"/> CREATIVE DJINNS
#
# # **Coding <span style="color:#3dbdac">Projekt</span> Ideen**
#
# ***
#
# ### **Generelle Anforderungen**
#
# **Bitte beachtet folgende Anforderungen, die für alle Anwendungen verbindlich sind.**
#
# 1. Freie Sprachauswahl | Python | Java | C# usw.
# 2. Bedienbare GUI
# 3. Freie Wahl zwischen Desktop- und Webanwendung
# 4. Login inklusive einer relationalen Datenbank
# 5. Bereitstellung über Github
#
# **Zielführende Kommunikation kann euch vor harten Kopfschmerzen schützen.**
#
# ***

# %% [markdown]
# ### **GUI Support**
#
# + Tkinter in Python
# + oder noch viel besser 👉🏽 [Custom Tkinter](https://github.com/TomSchimansky/CustomTkinter)
# + für die Webentwicklung 👉🏽 [Bootstrap](https://getbootstrap.com/)
#
# ***

# %% [markdown]
# ## **<span style="color:#3dbdac">Klassische Entwicklung</span>**

# %% [markdown]
# ### **1. Taschenrechner**
#
# <img src="./assets/calculator.png" style="height: 100px"/>
#
# **Projektbeschreibung**
#
# + Der Taschenrechner muss die Funktionalitäten des unten aufgeführten Screenshots abdecken
# + kein Import von irgendwelchen Bibliotheken
# + **alle mathematischen Funktionen selbst erstellen**
#
#
# ![image-5.png](attachment:image-5.png)  ![image.png](attachment:image.png)    ![image-4.png](attachment:image-4.png)
#
# **Recherche Links**
#
# [Github](https://github.com/microsoft/calculator)
#
# [Stack Overflow](https://stackoverflow.com/questions/tagged/calculator)
#
# ***

# %% [markdown]
# ### **2. Fractal Zoom | Mandelbrot - Menge**
#
# <img src="./assets/fraktal.png" style="height: 100px"/>
#
# **Projektbeschreibung**
#
# + Darstellung einer beliebigen oder mehreren Mandelbrot Mengen
# + Kaskadierung -> "Aufbau" nach innen bis der Prozessor quietscht (mindestens 7 Level)
#
# ***

# %% [markdown]
# ## **<span style="color:#3dbdac">Spielentwicklung</span>**

# %% [markdown]
# ### **1. Rock Paper Scissors**
#
# <img src="./assets/rock-paper-scissors.png" style="height: 100px"/>
#
# + Erstellung eines spielbaren Rock Paper Scissors
# + Auswahl der Handzeichen in der GUI
# + Bestenfalls mit Animationen
# + optionale Ressoucen werden im Ordner "rock_paper_scissor" bereit gestellt
#
# ***

# %% [markdown]
# ### **2. Pong**
#
# <img src="./assets/ping-pong.png" style="height: 100px"/>
#
# + Erstellung eines spielbaren Pongs
# + Auswahl zwischen Ein-Spieler-Modus gegen den Computer und einem Zwei-Spieler-Modus
# + Highscores werden mit Namen in einer Datenbank gespeichert
#
# ***

# %% [markdown]
# ### **3. Space Invaders**
#
# <img src="./assets/space.png" style="height: 100px"/>
#
# + Erstellung eines spielbaren Space Invaders
# + optional mit verschiedenen Leveln
# + Highscores werden mit Namen in einer Datenbank gespeichert
#
# ***

# %% [markdown]
# ### **4. Tetris**
#
# <img src="./assets/tetris.png" style="height: 100px"/>
#
# **Projektbeschreibung**
#
# + wer den Taschenrechner durchgespielt hat, der erstellt Tetris
# + die Random - Funktion muss selber erstellt werden - eventuell mit 3.14 😁
#
# ***

# %% [markdown]
# ### **5. Zauberwürfel Rubiks Cube**
#
# <img src="./assets/zaubertrick.png" style="height: 100px"/>
#
# **Projektbeschreibung**
#
# + das Bonuslevel nach Tetris
# + Zauberwürfel 9 x 9
#
# ***

# %% [markdown]
# ## **<span style="color:#3dbdac">Netzwerkentwicklung</span>**
#
# ### **1. RADIUS - Server Programmieren**
#
# Remote Authentication Dial-In User Service
#
# <img src="./assets/sicherheits-login.png" style="height: 100px"/>
#
# **Projektbeschreibung**
#
# "RADIUS steht für den englischen Begriff Remote Authentication Dial-In User Service\
# und bezeichnet einen Service, der User in einem Dial-In-Netzwerk authentifiziert und autorisiert.\
# RADIUS lässt sich auch für die Abrechnung (Accounting) von Services nutzen.\
# In Unternehmen wird RADIUS häufig für die Benutzer-Anmeldung in WLAN-Netzwerken eingesetzt."
#
# [Quelle](https://www.security-insider.de/wie-funktioniert-radius-a-613266/)
#
# + Login entwickeln
# + Benutzereingaben werden gegen eine Datenbank verifiziert
# + verschlüsselte Kommunikation | eventuell gehashed
#
# ***

# %% [markdown]
# ### **2. Passwort Manager**
#
# <img src="./assets/schlusselperson.png" style="height: 100px"/>
#
# **Projektbeschreibung**
#
# + für wen der RADIUS - Server kindergarten ist, der baut einen Passwort Manager
# + Passwort Generator
#
# ***

# %% [markdown]
# ### **3. Geräte Manager**
#
# <img src="./assets/hauptplatine.png" style="height: 100px"/>
#
# **Projektbeschreibung**
#
# + Gerätemanager
# + Treiber auslesen und anzeigen lassen
# + optionale Treiber aktualisierung
#
# ![image.png](attachment:image.png)
#
# ***

# %% [markdown]
# ### **4. Interpreter oder Compiler**
#
# <img src="./assets/compiler.png" style="height: 100px"/>
#
# **Projektbeschreibung**
#
# + die Entwicklung findet nur in der C Familie statt
#
# ***

# %% [markdown]
# ### **5. BIOS**
#
# <img src="./assets/bios.png" style="height: 100px"/>

# %% [markdown]
# ***
